# %% [markdown]
# ## MTA Self Assessment data

# %%
import pandas as pd
import re
import string
import warnings

from bokeh.io import output_notebook
from bokeh.layouts import gridplot
from bokeh.models import HoverTool, ColumnDataSource, FuncTickFormatter, DatetimeTickFormatter, Label
from bokeh.palettes import Category10, gray
from bokeh.plotting import Figure, show, figure
from datetime import datetime, timedelta

# %%
# load general variables
subway_lines = 'ABCDEFGJLMNQRSWZ1234567'
subway_colors = {
    'A': '#0039A6',
    'B': '#FF6319',
    'C': '#0039A6',
    'D': '#FF6319',
    'E': '#0039A6',
    'F': '#FF6319',
    'G': '#6CBE45',
    'J': '#996633',
    'L': '#A7A9AC',
    'M': '#FF6319',
    'N': '#FCCC0A',
    'Q': '#FCCC0A',
    'R': '#FCCC0A',
    'S': '#808183',
    'Z': '#996633',
    'W': '#FCCC0A',
    '1': '#EE352E',
    '2': '#EE352E',
    '3': '#EE352E',
    '4': '#00933C',
    '5': '#00933C',
    '6': '#00933C',
    '7': '#B933AD'
}

# %%
# load visualization tools & settings
#output_notebook()
warnings.filterwarnings('ignore')

# %%
mta_data = pd.read_csv('../data/MTA_Performance_NYCT.csv', encoding='latin1')

# %%
mta_data.head(2)
# Out:
#    INDICATOR_SEQ  PARENT_SEQ  AGENCY_NAME  \
# 0          67816           0  NYC Transit
# 1          67816           0  NYC Transit
#
#                              INDICATOR_NAME  \
# 0  Mean Distance Between Failures - Subways
# 1  Mean Distance Between Failures - Subways
#
#                                          DESCRIPTION            CATEGORY  \
# 0  Average number of miles a subway car travels i...  Service Indicators
# 1  Average number of miles a subway car travels i...  Service Indicators
#
#   FREQUENCY DESIRED_CHANGE INDICATOR_UNIT  DECIMAL_PLACES  PERIOD_YEAR  \
# 0         M              U              -               0         2008
# 1         M              U              -               0         2008
#
#    PERIOD_MONTH  YTD_TARGET  YTD_ACTUAL  MONTHLY_TARGET  MONTHLY_ACTUAL
# 0             1    148244.0    148244.0        155000.0        148420.0
# 1             2    148476.0    148476.0        155000.0        140993.0

# %%
mta_data['date'] = mta_data[
    ['PERIOD_YEAR','PERIOD_MONTH']
].apply(lambda x: datetime(x[0], x[1], 1), axis=1)

# %%
mta_data['INDICATOR_NAME'].unique()
# Out:
# array(['Mean Distance Between Failures - Subways',
#        'Wait Assessment - Subways (Inactive, Historic Calculations)',
#        'Customer Injury Rate - Subways',
#        'Mean Distance Between Failures - Staten Island Railway ',
#        'On-Time Performance - Staten Island Railway',
#        'Employee Lost Time and Restricted Duty Rate ',
#        'Total Ridership - Subways',
#        'Mean Distance Between Failures - NYCT Bus',
#        'Total Paratransit Ridership - NYCT Bus',
#        'Customer Accident Injury Rate - NYCT Bus',
#        'Total Ridership - NYCT Bus ', 'Elevator Availability - Subways',
#        'Escalator Availability - Subways',
#        'Collisions with Injury Rate - NYCT Bus',
#        '% of Completed Trips - NYCT Bus',
#        'East New York Depot - % of Completed Trips',
#        'Flatbush Depot - % of Completed Trips',
#        'Jackie Gleason Depot - % of Completed Trips',
#        'Ulmer Park Depot - % of Completed Trips',
#        'Fresh Pond Depot - % of Completed Trips',
#        'Yukon Depot - % of Completed Trips',
#        '126th Street Depot - % of Completed Trips ',
#        'Casey Stengel Depot - % of Completed Trips',
#        'Jamaica Depot - % of Completed Trips',
#        'Castleton Depot - % of Completed Trips',
#        'Queens Village Depot - % of Completed Trips',
#        'Kingsbridge Depot - % of Completed Trips',
#        'Manhattanville Depot - % of Completed Trips',
#        'Gun Hill Depot - % of Completed Trips',
#        'Michael J. Quill Depot - % of Completed Trips',
#        'Charleston Depot - % of Completed Trips',
#        'Meredith Avenue Depot - % of Completed Trips',
#        '100th Street Depot - % of Completed Trips',
#        'West Farms Depot - % of Completed Trips',
#        'Grand Avenue Depot - % of Completed Trips',
#        ' Bus Passenger Wheelchair Lift Usage - NYCT Bus',
#        'On-Time Performance (Terminal)', 'OTP (Terminal) - 1 Line',
#        'OTP (Terminal) - 2 Line', 'OTP (Terminal) - 3 Line',
#        'OTP (Terminal) - 4 Line', 'OTP (Terminal) - 5 Line',
#        'OTP (Terminal) - 6 Line', 'OTP (Terminal) - 7 Line',
#        'OTP (Terminal) - S Line 42 St.', 'OTP (Terminal) - A Line',
#        'OTP (Terminal) - B Line', 'OTP (Terminal) - C Line',
#        'OTP (Terminal) - D Line', 'OTP (Terminal) - E Line',
#        'OTP (Terminal) - F Line', 'OTP (Terminal) - S Fkln Line',
#        'OTP (Terminal) - G Line', 'OTP (Terminal) - J Z Line',
#        'OTP (Terminal) - L Line', 'OTP (Terminal) - M Line',
#        'OTP (Terminal) - N Line', 'OTP (Terminal) - Q Line',
#        'OTP (Terminal) - R Line', 'OTP (Terminal) - S Line Rock',
#        'Subway Wait Assessment ', 'Subway Wait Assessment - 1 Line',
#        'Subway Wait Assessment - 2 Line',
#        'Subway Wait Assessment - 3 Line',
#        'Subway Wait Assessment - 4 Line',
#        'Subway Wait Assessment - 5 Line',
#        'Subway Wait Assessment - 6 Line',
#        'Subway Wait Assessment - 7 Line',
#        'Subway Wait Assessment - S 42 St',
#        'Subway Wait Assessment - A Line',
#        'Subway Wait Assessment - B Line',
#        'Subway Wait Assessment - C Line',
#        'Subway Wait Assessment - D Line',
#        'Subway Wait Assessment - E Line',
#        'Subway Wait Assessment - F Line',
#        'Subway Wait Assessment - G Line',
#        'Subway Wait Assessment - S Rock ',
#        'Subway Wait Assessment - J Z Line',
#        'Subway Wait Assessment - L Line',
#        'Subway Wait Assessment - M Line',
#        'Subway Wait Assessment - N Line',
#        'Subway Wait Assessment - Q Line',
#        'Subway Wait Assessment - R Line', 'Subway Wait Assessment - S Fkln'], dtype=object)

# %%
otp_data = mta_data[mta_data['INDICATOR_NAME'].str.contains('OTP')]

# %%
# On Time Performance by line

plot_list = []
for d in subway_lines:
    if d != 'J'and d != 'S' and d != 'W':
        _plot = figure(
            plot_width=250, 
            plot_height=150, 
            y_range = (0,100), 
            title=d, 
            y_minor_ticks=2, 
            x_axis_type='datetime')
        _plot.line(
            x=otp_data['date'][otp_data['INDICATOR_NAME'].str.contains(d + ' Line')] ,
            y=otp_data['MONTHLY_ACTUAL'][otp_data['INDICATOR_NAME'].str.contains(d + ' Line')],
            line_color=subway_colors[d],
            line_width=3
        )
        
        _plot.xaxis.formatter=DatetimeTickFormatter(years='%y')
        plot_list.append(_plot)
        
grid = gridplot(plot_list, ncols=5, plot_width=250, plot_height=150)
show(grid)

# %%
otp_data['line'] = otp_data['INDICATOR_NAME'].apply(lambda x: x[17:18])

# %%
# wait assessment
assessment_data = mta_data[mta_data['INDICATOR_NAME'].str.contains('Assessment - ')]
plot_list = []
for d in subway_lines:
    if d != 'J'and d != 'S' and d != 'W':
        _plot = figure(
            plot_width=250, 
            plot_height=150, 
            y_range = (60,90), 
            title=d, 
            y_minor_ticks=2, 
            x_axis_type='datetime')
        _plot.line(
            x=assessment_data['date'][assessment_data['INDICATOR_NAME'].str.contains(d + ' Line')] ,
            y=assessment_data['MONTHLY_ACTUAL'][assessment_data['INDICATOR_NAME'].str.contains(d + ' Line')],
            line_color=subway_colors[d],
            line_width=3
        )
        
        _plot.xaxis.formatter=DatetimeTickFormatter(years='%y')
        plot_list.append(_plot)
        
grid = gridplot(plot_list, ncols=5, plot_width=250, plot_height=150)
show(grid)

# %% [markdown]
# ### Let's look at On-Time Performance vs count of disruptions as a sanity check

# %%
# performance stats vs alerts
alert_data = pd.read_csv('../data/my_mta_data_for_analysis.csv')
alert_data.head(2)
# Out:
#    Unnamed: 0   count  hex_x  \
# 0      190003  182417  2c891
# 1      190006  182420  2c894
#
#                                                title  \
# 0      UPDATED: BKLYN, 2,3 & 4 Trains, Sick Customer
# 1  UPDATED: MANH, 1, 2 and 3 Trains, Signal Probl...
#
#                                                 body  \
# 0            Following an earlier incident at Ber...
# 1           b/d 1,  2 and 3 trains are running wi...
#
#                                                  msg system  \
# 0  Following an earlier incident at Bergen St,  2...    NYC
# 1  b/d 1,  2 and 3 trains are running with delays...    NYC
#
#                   time  hex_y  planned work       ...        \
# 0  2014-09-01 00:10:00  2c891         False       ...
# 1  2014-09-01 00:26:00  2c894         False       ...
#
#    unauthorized person  event  sick customer  update  non service  \
# 0                False  False           True    True        False
# 1                False  False          False    True        False
#
#    construction  weather  other agencies  other       estimated
# 0         False    False           False  False  end disruption
# 1         False    False           False  False          signal
#
# [2 rows x 44 columns]

# %%
# Find subway lines mentioned
regex = re.compile('[%s]' % re.escape(string.punctuation))
def extract_subway_lines(txt, subway_lines=subway_lines):
    cleaned_txt = regex.sub(' ', txt)
    split_txt = cleaned_txt.split()
    if 'All' in split_txt:
        return [s for s in subway_lines]
    else:
        return [s for s in split_txt if s in subway_lines]
    
alert_data['lines'] = alert_data['title'].apply(
    lambda x: extract_subway_lines(x)
)

# %%
# create monthly field
alert_data['month'] = alert_data['time'].apply(lambda x: datetime(pd.to_datetime(x).year, pd.to_datetime(x).month, 1))

# %%
# alerts by line by month
disruption_by_line = []

def generate_disruption_list(disruption, lines, month, disruption_by_line= disruption_by_line):
    for line in lines:
        disruption_by_line.append({"line": line, "disruption": disruption, "count": 1, "month" : month})
    return None

alert_data_ex = alert_data[
    (~alert_data['estimated'].isin(['planned service change','non service','retraction'])) 
    & (~alert_data['update'])
]

alert_data_ex[['estimated', 'lines', 'month']].apply(
    lambda x: generate_disruption_list(x[0],x[1],x[2]), axis=1
)

disruption_df = pd.DataFrame(disruption_by_line)
disruption_df.head()
# Out:
#    count         disruption line      month
# 0      1  equipment problem    2 2014-09-01
# 1      1      sick customer    J 2014-09-01
# 2      1             signal    N 2014-09-01
# 3      1              event    2 2014-09-01
# 4      1              event    3 2014-09-01

# %%
disruption_by_line_by_month = disruption_df.drop(
    ['disruption'], 
    axis=1
).groupby(['line','month']).count().reset_index()

# %%
alerts_vs_otp = disruption_by_line_by_month.merge(
    right=otp_data[['line', 'date', 'MONTHLY_ACTUAL']], 
    left_on=['month', 'line'],
    right_on=['date', 'line'],
    how = 'inner')

# %%
# include updates, avg corr = -.31
# exclude updates, avg corr = -.38
# include updates and end-of-disruption = -.39
# exclude updates but include end-of-disruption = ~.48 (ex R, -.52)
plot_list = []
avg_corr = []
for d in subway_lines:
    if d != 'Z'and d != 'S' and d != 'W':
        
        _otp = alerts_vs_otp[alerts_vs_otp['line'] == d][['count', 'MONTHLY_ACTUAL']]
        print(d + ': ' + str(round(_otp.corr()['count'][1],5)))
        avg_corr.append(_otp.corr()['count'][1])
        
        _plot = figure(
            plot_width=200, 
            plot_height=170, 
            x_range = (0,100),
            y_range = (25,100), 
            title=d, 
            y_minor_ticks=2)
        _plot.scatter(
            x=_otp['count'],
            y=_otp['MONTHLY_ACTUAL'],
            line_color=subway_colors[d],
            line_width=3
        )
        text_annotate = Label(text=str(round(_otp.corr()['count'][1],2)),  x=65, y=88)
        _plot.add_layout(text_annotate)
        
        plot_list.append(_plot)

print('Mean Correlation: ' + str(round(sum(avg_corr)/len(avg_corr),4)))
grid = gridplot(plot_list, ncols=5, plot_width=200, plot_height=170)
show(grid)
# Out:
# A: -0.52958
# B: -0.52542
# C: -0.38095
# D: -0.54041
# E: -0.56095
# F: -0.81515
# G: -0.21825
# J: -0.67211
# L: -0.64016
# M: -0.70634
# N: -0.38051
# Q: -0.34638
# R: 0.3781
# 1: -0.64634
# 2: -0.52945
# 3: -0.57132
# 4: -0.64114
# 5: -0.60167
# 6: -0.06261
# 7: -0.57662
# Mean Correlation: -0.4784

# %%
def find_trainline(cell, line):
    try:
        cell.index(line)
        return True
    except ValueError:
        return False

r_line_alerts = alert_data['msg'][alert_data['lines'].apply(lambda x: find_trainline(x, 'R'))]

# %%
r_line_alerts[200:300].apply(lambda x: print(x))
# Out:
# b/d D,  N,  Q & R delays and service changes,  due to track maintenance at DeKalb Av. Details at www.mta.info.
# b/d D,  N,  Q & R delays and service changes,  due to track maintenance at DeKalb Av. Details at www.mta.info.
# b/d D,  N,  Q & R delays and service changes,  due to track maintenance at DeKalb Av. Details at www.mta.info.
# Following an earlier incident at DeKalb Av,  D,  N,  Q & R train service has resumed with residual delays.
# b/d,  D,  N & R delayed,  s/b,  some N terminating at Canal St,  some R terminating at Whitehall St,  track maintenance at DeKalb Av. Allow additional travel time.
# b/d,  D,  N & R delayed,  s/b,  some N terminating at Canal St,  some R terminating at Whitehall St,  track maintenance at DeKalb Av. Allow additional travel time.
# b/d,  D,  N & R delayed,  s/b,  some N terminating at Canal St,  some R terminating at Whitehall St,  track maintenance at DeKalb Av. Allow additional travel time.
# Following an earlier incident at DeKalb Av,  D,  N and R train service has resumed with residual delays.
# s/b M and R trains are running with delays,  due to signal problems at 46 St. Allow additional travel time.
# Following an earlier incident at 46 St,  M and R train service has resumed with residual delays.
# b/d E,  F,  M and R delays and service changes,  due to a rail condition at 46 St. Details at mta.
# b/d E,  F,  M and R delays and service changes,  due to a rail condition at 46 St. Details at mta.
# Following an earlier incident at 46 St,  E,  F,  M and R train service has resumed with delays.
# E,  F,  M and R trains delayed and rerouted due to signal problems at 71 Av. Details at www.mta.info.
# Following an earlier incident at 71 Av,  E,  F,  M and R train service has resumed  with residual delays.
# Forest Hills bound M & n/b R trains are running with delays,  due to signal problems at 71 Av. Allow additional travel time.
# Forest Hills bound M & n/b R trains are running with delays,  due to signal problems at 71 Av. See mta.
# Forest Hills bound M & n/b R trains are running with delays,  due to signal problems at 71 Av. See mta.
# Following an earlier incident at 71 Av,  M & R train service has resumed with residual delays.
# Due to an earlier incident at 63 Dr,  M and R train service has resumed with delays.
# s/b N trains express 34 St to Canal St,  s/b R trains via Q line from 34 St to Atlantic Av due to FDNY activity at 14 St-Union Sq. See mta.
# Following an earlier incident at 14 St-Union Sq,  N,  Q & R train service has resumed with residual delays.
# s/b R trains are running with delays due to a sick customer at 25 St. Allow additional travel time.
# s/b R via N from Canal St to 36 St (Bklyn) due to a sick customer at 25 St. Allow additional travel time.
# Following an earlier incident at 25 St,  R train service has resumed with residual delays.
# s/b D,  N,  R & Q train service changes,  due to track maintenance at Atlantic Av-Barclays Ctr. Details at mta.
# s/b D,  N,  R & Q train service changes,  due to track maintenance at Atlantic Av-Barclays Ctr. Details at mta.
# s/b D,  N,  R & Q train service changes,  due to track maintenance at Atlantic Av-Barclays Ctr. Details at mta.
# s/b D,  N,  R & Q train service changes,  due to track maintenance at Atlantic Av-Barclays Ctr. Details at mta.
# Following an earlier incident at Atlantic Av-Barclays Ctr,  D,  N,  R & Q train service has resumed with residual delays.
# Following an earlier incident at Atlantic Av-Barclays Ctr,  D,  N,  R & Q train service has resumed with residual delays.
# 11:45 PM to 5 AM,  Mon to Fri,  Oct 27 – 31 No R trains in Brooklyn between 59 St and 36 St – take the N. R trains run between Bay Ridge-95 St and 59 St,  Brooklyn.
# n/b D,  N and R trains are running with delays,  due to track maintenance at Atlantic Av. Allow additional travel time.
# n/b D,  N and R delays & some s/b R terminate at Whitehall St,  due to track maintenance at Atlantic Av. Allow additional travel time.
# n/b D,  N and R delays & some s/b R terminate at Whitehall St,  due to track maintenance at Atlantic Av. Allow additional travel time.
# n/b D,  N and R delays & some s/b R terminate at Whitehall St,  due to track maintenance at Atlantic Av. Allow additional travel time.
# n/b D,  N and R delays & some s/b R terminate at Whitehall St,  due to track maintenance at Atlantic Av. Allow additional travel time.
# n/b D,  N and R delays & some s/b R terminate at Whitehall St due to ongoing track maintenance at Atlantic Av. Allow additional travel time.
# n/b D,  N and R delays & some s/b R terminate at Whitehall St due to ongoing track maintenance at Atlantic Av. Allow additional travel time.
# n/b D,  N and R delays & some s/b R terminate at Whitehall St due to ongoing track maintenance at Atlantic Av. Allow additional travel time.
# Following an earlier incident at Atlantic Av-Barclays Center,  D,  N and R train service has resumed with residual delays.
# b/d,  D,  N & R trains are running with delays due to track maintenance at Atlantic Av. Allow additional travel time.
# b/d,  D,  N & R trains are running with delays due to track maintenance at Atlantic Av. Allow additional travel time.
# b/d,  D,  N & R trains are running with delays due to track maintenance at Atlantic Av. Allow additional travel time.
# b/d,  D,  N & R trains are running with delays due to track maintenance at Atlantic Av. Allow additional travel time.
# b/d,  D,  N & R trains are running with delays due to track maintenance at Atlantic Av. Allow additional travel time.
# b/d,  D,  N & R trains are running with delays due to track maintenance at Atlantic Av. Allow additional travel time.
# b/d,  D,  N & R trains are running with delays due to track maintenance at Atlantic Av. Allow additional travel time.
# Following an earlier incident at Atlantic Av-Barclays Ctr,  D,  N and R train service has resumed with residual delays.
# s/b R trains via Q line from Canal St to DeKalb Av due to a sick customer at Union St. Allow additional travel time.
# Following an earlier incident at Union St,  R train service has resumed with residual delays.
# n/b,  N,  Q & R trains delayed due to a rail condition at 34 St. Allow additional travel time.
# Following an earlier incident at 34 St-Herald Square,  N,  Q and R train service has resumed with residual delays.
# n/b N and R trains exp from 42 St to 57 St-7 Av,  due to FDNY activity at 49 St. Allow additional travel time.
# Following an earlier incident at 49 St,  N and R train service has resumed with residual delays.
# n/b R trains exp from 36 St (Bklyn) to Atlantic Av,  due to a sick customer at Prospect Av. Allow additional travel time.
# Following an earlier incident at Prospect Av,  R train service has resumed with residual delays.
# b/d,  E,  F,  M & R trains delayed and rerouted due to a train with mechanical problems at 21 St. See mta.info for details.
# b/d,  E,  F,  M & R trains delayed and rerouted due to a train with mechanical problems at 21 St. See mta.info for details.
# 6:30 AM to 12:15 AM,  Sat to Mon,  Nov 1 – 3 71 Av-bound R trains run express from Queens Plaza to Roosevelt Av.
# Following an earlier incident at 21 St-Queensbridge,  E,  F,  M and R train service has resumed with residual delays.
# n/b,  E,  F & R trains delayed due to NYPD activity at Roosevelt Av. Allow additional travel time.
# Following an earlier incident at Jackson Heights-Roosevelt Av,  E,  F and R train service has resumed with residual delays.
# s/b R via F Roosevelt Av to 57 St,  s/b N & Q terminate at Queensboro Plaza,  due to train with mechanical problems at Lex/59 St. Allow additional travel time.
# Following an earlier incident at Lexington Av-59 St,  N,  Q and R train service has resumed with delays.
# s/b N,  Q & R delays,  s/b N & Q via R from Canal St to DeKalb Av due to a rail condition at Canal St. Allow additional travel time.
# s/b N,  Q & R delays,  s/b N & Q via R from Canal St to DeKalb Av due to a rail condition at Canal St. Allow additional travel time.
# s/b N,  Q & R delays,  s/b N & Q via R from Canal St to DeKalb Av due to a rail condition at Canal St. Allow additional travel time.
# Following an earlier incident at Canal St,  N,  Q and R train service has resumed with residual delays.
# b/d,  no N & R train service b/t DeKalb Av & Whitehall,  due to switch problems on the MANH Bridge. Allow additional travel time.
# b/d,  no N & R train service b/t DeKalb Av & Whitehall,  due to a train with mechanical problems on the MANH Bridge. Allow additional travel time.
# Following an earlier incident on the MANH Bridge,  N & R train service has resumed with residual delays.
# n/b N,  Q & R trains are running with delays due to a train with mechanical problems at Prince St. Allow additional travel time.
# n/b N,  Q & R service changes and delays due to a train with mechanical problems at Prince St. See mta.
# Following an earlier incident at Prince St,  N,  Q & R train service has resumed with residual delays.
# s/b N & R trains express from 34 St to Canal St due to an investigation at 14 St-Union Sq. Allow additional travel time.
# Following an earlier incident at 14 St-Union Sq,  N & R train service has resumed with residual delays.
# n/b N,  Q and R trains are running with delays due to a rail condition at 5 Av-59 St. Allow additional travel time.
# b/d,  no N & Q trains b/t 57 St & 5 Av,  R via F from 57 St to 36 St (QNS) due to a rail condition at 5 Av-59 St. See mta.
# b/d,  no N & Q trains b/t 57 St & Queensboro Plz,  n/b R via F from 57 St to 36 St (QNS) due to a rail condition at 5 Av. See mta.
# b/d,  no N & Q trains b/t 57 St & Queensboro Plz,  n/b R via F from 57 St to 36 St (QNS) due to a rail condition at 5 Av. See mta.
# n/b N & R trains are running express from Times Sq-42 St to 57 St-7 Av,  due to a broken rail at 49 St.
# n/b N & R trains are running express from Times Sq-42 St to 57 St-7 Av,  due to a rail condition at 49 St.
# Following an earlier incident at 49 St,  N & R train service has resumed with residual delays.
# s/b N and R trains are running express from Canal St to Dekalb Av,  due to track maintenance at Canal St.
# Following an earlier incident at Canal St,  N and R train service has resumed with residual delays.
# b/d,  R trains are running with delays due to track maintenance at 45 St. Allow additional travel time.
# b/d,  R trains are running with delays due to track maintenance at 45 St. Allow additional travel time.
# b/d R trains are running with delays,  some s/b R via N from Prince St to 59 St (Bklyn),  due to track maintenance at 45 St. Allow additional travel time.
# b/d R trains are running with delays,  some s/b R via N Prince St to 59 St (Bklyn),  track maintenance at 45 St. See mta.
# Following an earlier incident at 45 St,  R train service has resumed with residual delays.
# n/b N,  Q and R trains are running express from Canal St to 57 St-7 Av,  due to a train with mechanical problems at 34 St-Herald Sq.
# Following an earlier incident at 34 St-Herald Sq,  N,  Q and R train service has resumed with residual delays.
# s/b,  R trains running with delays due to a train with mechanical problems at 36 St (BKLYN). Allow additional travel time.
# Following an earlier incident at 36 St (BKLYN),  R train service has resumed with residual delays.
# 11:45 PM to 5 AM,  Mon to Fri,  Nov 10 – 14 No R trains in Brooklyn between 59 St and 36 St — take the N. R trains run between Bay Ridge-95 St and 59 St,  Brooklyn.
# b/d,  D,  N and R trains delayed due to track maintenance at 25 St. Allow additional travel time.
# b/d,  D,  N and R trains delayed due to track maintenance at 25 St. Allow additional travel time.
# b/d,  D,  N and R trains delayed due to ongoing track maintenance at 25 St. Allow additional travel time.
# n/b,  R via F from 57 St to 36 St (QNS),  N terminating at 57 St due to a sick customer at Lexington Av. Allow additional travel time.
# 2474    None
# 2475    None
# 2482    None
# 2484    None
# 2501    None
# 2502    None
# 2503    None
# 2510    None
# 2525    None
# 2528    None
# 2544    None
# 2546    None
# 2547    None
# 2595    None
# 2596    None
# 2637    None
# 2640    None
# 2645    None
# 2646    None
# 2660    None
# 2661    None
# 2662    None
# 2665    None
# 2667    None
# 2669    None
# 2740    None
# 2741    None
# 2746    None
# 2748    None
# 2751    None
#         ...
# 3264    None
# 3265    None
# 3269    None
# 3270    None
# 3273    None
# 3321    None
# 3324    None
# 3335    None
# 3336    None
# 3337    None
# 3340    None
# 3345    None
# 3346    None
# 3348    None
# 3354    None
# 3356    None
# 3369    None
# 3370    None
# 3371    None
# 3372    None
# 3373    None
# 3407    None
# 3409    None
# 3445    None
# 3452    None
# 3453    None
# 3477    None
# 3481    None
# 3484    None
# 3487    None
# Name: msg, Length: 100, dtype: object
